# %%
from src.data_loader import load_data
import os

print(os.getcwd())

df = load_data()

df.head()

df.to_csv("../data/processed/epl_loaded.csv", index=False)
# Out:
# C:\Users\Ross Wadhams\OneDrive\Portfolio work\EPL predictor\EPLInsightEngine\notebooks
# ['../data/raw\\PL 21-22.csv', '../data/raw\\PL 22-23.csv', '../data/raw\\PL 23-24.csv', '../data/raw\\PL 24-25.csv', '../data/raw\\Pl 25-26.csv']
# Hello
